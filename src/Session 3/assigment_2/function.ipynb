# %% [markdown]
# Function

# %%
class A:
    def do_this (self)
        print("A")

class B(A)
            pass
Class c ():
            def do_this(self)
                print("C")
# Out:
#   Cell In[1], line 2
#     def do_this (self)
#                       ^
# SyntaxError: expected ':'

# %%
print ("hallo")
# Out:
# hallo

# %%
import os 
path = "tmp_directory"

if not os.path.exists(path):
    os.markedirs(pase)
    for i in range (20):
        inner_path = os.path.join(path."dir_" + str(i))
        if not

# %%
from abc Import ABC,

# %%
with open ("temp_directory/text1.text","a+") as file ; #"w+" "r+"ArithmeticError
    file.write (" New line added\n ")
    file.seek(0)
    updated_contnt = file.read()
    print (updated_contant)
# Out:
#   Cell In[8], line 1
#     with open ("temp_directory/text1.text","a+") as file ; #"w+" "r+"ArithmeticError
#                                                          ^
# SyntaxError: invalid syntax
